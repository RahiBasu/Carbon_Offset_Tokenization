# %% [markdown]
# <a href="https://colab.research.google.com/github/RahiBasu/Carbon_Offset_Tokenization/blob/main/SynapseSprint_%3CTech_Hunters%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn prophet pandas matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6714fb9b-5499-4a57-ad4a-538f04bd33ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6714fb9b-5499-4a57-ad4a-538f04bd33ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("SurveySchema.csv", low_memory=False)
df.head()
# Out:
#   2018 Kaggle Machine Learning and Data Science Survey  \
# 0                                          Question:
# 1                                  # of Respondents:
# 2  Who was excluded? (0 = not excluded; 1 = exclu...
# 3  If What is your age (# years)? 0-17 Is Selecte...
# 4  If What is the highest level of formal educati...
#
#                                        Q1  \
# 0  What is your gender? - Selected Choice
# 1                                   23860
# 2                                       0
# 3                                       0
# 4                                       0
#
#                                                  Q10  \
# 0  Does your current employer incorporate machine...
# 1                                              20670
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#                                                  Q11  \
# ...

# %%
df = df.iloc[1:]

# %%
df['Year'] = 2025
df_tools = df[['Year', 'Q17']].dropna()

# %%
df_tools['Q17'] = df_tools['Q17'].str.split(';')
df_tools = df_tools.explode('Q17')

tool_counts = df_tools.groupby(['Year', 'Q17']).size().reset_index(name='Count')
tool_counts = tool_counts.rename(columns={'Q17': 'Tool'})
tool_counts.sort_values(by='Count', ascending=False).head()
# Out:
#    Year   Tool  Count
# 0  2025      0      9
# 1  2025      1      1
# 2  2025  15223      1

# %%
df_tool['ds'] = pd.to_datetime(df_tool['ds'], errors='coerce')

# %%
tools = tool_counts['Tool'].unique()
years = range(2021, 2026)

simulated_data = []

for tool in tools:
    base = np.random.randint(50, 500)
    for year in years:
        growth = np.random.normal(loc=base + (year - 2021) * 20, scale=15)
        simulated_data.append([year, tool, max(0, int(growth))])

df_simulated = pd.DataFrame(simulated_data, columns=['Year', 'Tool', 'Count'])

# %%
df_tool = df_tool[['ds', 'y']].dropna()
print("Number of valid rows:", len(df_tool))
print(df_tool)
if len(df_tool) >= 2:
    model = Prophet()
    model.fit(df_tool)

    future = model.make_future_dataframe(periods=1, freq='Y')
    forecast = model.predict(future)

    model.plot(forecast)
    plt.title(f"Forecast for {tool_name} Usage")
    plt.xlabel("Year")
    plt.ylabel("Count")
    plt.grid(True)
    plt.show()
else:
    print(f"Not enough data to forecast {tool_name}. Need at least 2 non-NaN rows.")
# Out:
# Number of valid rows: 0
# Empty DataFrame
# Columns: [ds, y]
# Index: []
# Not enough data to forecast Python. Need at least 2 non-NaN rows.
